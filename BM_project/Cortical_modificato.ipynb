# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %%
# !conda install -c conda-forge nest-simulator
# !conda install -c conda-forge matplotlib
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - nest-simulator
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     ca-certificates-2024.12.14 |       hbcca054_0         153 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     cmake-3.30.1               |       hf8c4bd3_0        18.3 MB  conda-forge
#     gsl-2.7                    |       he838d99_0         3.2 MB  conda-forge
#     h5py-3.12.1                |nompi_py310h60e0fe6_103         1.2 MB  conda-forge
#     hdf5-1.14.3                |nompi_hdf9ad27_105         3.7 MB  conda-forge
#     libaec-1.1.3               |       h59595ed_0          35 KB  conda-forge
#     libarchive-3.7.4           |       hfca40fe_0         851 KB  conda-forge
#     libblas-3.9.0              |26_linux64_openblas          16 KB  conda-forge
#     libcap-2.71                |       h39aace5_0         100 KB  conda-forge
#     libcblas-3.9.0             |26_linux64_openblas          16 KB  conda-forge
#     libcurl-8.8.0              |       hca28451_0         396 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libexpat-2.6.4             |       h5888daf_0          72 KB  conda-forge
#     libfabric-1.22.0           |       ha770c72_3          13 KB  conda-forge
#     libfabric1-1.22.0          |       ha594dbc_3         629 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgcrypt-lib-1.11.0       |       hb9d3cd8_2         572 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_1          53 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_1          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hd5240d6_1         1.4 MB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     libgpg-error-1.51          |       hbd13f7d_1         262 KB  conda-forge
#     libhwloc-2.11.2            |default_he43201b_1000         2.3 MB  conda-forge
#     liblapack-3.9.0            |26_linux64_openblas          16 KB  conda-forge
#     liblzma-5.6.3              |       hb9d3cd8_1         109 KB  conda-forge
#     libnghttp2-1.58.0          |       h47da74e_0         617 KB  conda-forge
#     libnl-3.11.0               |       hb9d3cd8_0         724 KB  conda-forge
#     libopenblas-0.3.28         |pthreads_h94d23a6_1         5.3 MB  conda-forge
#     libsolv-0.7.30             |       h3509ff9_0         460 KB  conda-forge
#     libsqlite-3.47.2           |       hee588c1_0         853 KB  conda-forge
#     libssh2-1.11.1             |       hf672d98_0         297 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libsystemd0-256.9          |       h2774228_0         401 KB  conda-forge
#     libtool-2.4.7              |       he02047a_1         404 KB  conda-forge
#     libudev1-256.9             |       h9a4d06a_2         138 KB  conda-forge
#     libuv-1.49.2               |       hb9d3cd8_0         864 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libxml2-2.12.7             |       h4c95cb1_3         689 KB  conda-forge
#     libzlib-1.3.1              |       hb9d3cd8_2          60 KB  conda-forge
#     mpi-1.0                    |          openmpi           4 KB  conda-forge
#     ncurses-6.5                |       he02047a_1         868 KB  conda-forge
#     nest-simulator-3.8         |  py310h93aa6d4_1        13.5 MB  conda-forge
#     numpy-2.2.1                |  py310h5851e9f_0         7.5 MB  conda-forge
#     openmpi-5.0.6              |     hd45feaf_100         4.3 MB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
#     pandas-2.2.3               |  py310h5eaa309_1        12.4 MB  conda-forge
#     patsy-1.0.1                |     pyhd8ed1ab_1         182 KB  conda-forge
#     python-3.10.16             |he725a3c_1_cpython        24.0 MB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhff2d567_1         217 KB  conda-forge
#     python-tzdata-2024.2       |     pyhd8ed1ab_1         139 KB  conda-forge
#     pytz-2024.1                |     pyhd8ed1ab_0         184 KB  conda-forge
#     rdma-core-55.0             |       h5888daf_0         1.2 MB  conda-forge
#     rhash-1.4.5                |       hb9d3cd8_0         183 KB  conda-forge
#     scipy-1.14.1               |  py310hfcf56fc_2        16.0 MB  conda-forge
#     six-1.17.0                 |     pyhd8ed1ab_0          16 KB  conda-forge
#     statsmodels-0.14.4         |  py310hf462985_0        10.4 MB  conda-forge
#     tk-8.6.13                  |       h2797004_0         3.1 MB  conda-forge
#     ucc-1.3.0                  |       h0f835a6_3         7.7 MB  conda-forge
#     ucx-1.17.0                 |       h53fb5aa_4         6.9 MB  conda-forge
#     zstandard-0.23.0           |  py310ha39cb0e_1         399 KB  conda-forge
#     zstd-1.5.6                 |       ha6fb4c9_0         542 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       162.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cmake              conda-forge/linux-64::cmake-3.30.1-hf8c4bd3_0
#   gsl                conda-forge/linux-64::gsl-2.7-he838d99_0
#   h5py               conda-forge/linux-64::h5py-3.12.1-nompi_py310h60e0fe6_103
#   hdf5               conda-forge/linux-64::hdf5-1.14.3-nompi_hdf9ad27_105
#   libaec             conda-forge/linux-64::libaec-1.1.3-h59595ed_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-26_linux64_openblas
#   libcap             conda-forge/linux-64::libcap-2.71-h39aace5_0
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-26_linux64_openblas
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libexpat           conda-forge/linux-64::libexpat-2.6.4-h5888daf_0
#   libfabric          conda-forge/linux-64::libfabric-1.22.0-ha770c72_3
#   libfabric1         conda-forge/linux-64::libfabric1-1.22.0-ha594dbc_3
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.0-hb9d3cd8_2
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_1
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_1
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hd5240d6_1
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.51-hbd13f7d_1
#   libhwloc           conda-forge/linux-64::libhwloc-2.11.2-default_he43201b_1000
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-26_linux64_openblas
#   liblzma            conda-forge/linux-64::liblzma-5.6.3-hb9d3cd8_1
#   libnl              conda-forge/linux-64::libnl-3.11.0-hb9d3cd8_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.28-pthreads_h94d23a6_1
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libsystemd0        conda-forge/linux-64::libsystemd0-256.9-h2774228_0
#   libtool            conda-forge/linux-64::libtool-2.4.7-he02047a_1
#   libudev1           conda-forge/linux-64::libudev1-256.9-h9a4d06a_2
#   libuv              conda-forge/linux-64::libuv-1.49.2-hb9d3cd8_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   mpi                conda-forge/linux-64::mpi-1.0-openmpi
#   nest-simulator     conda-forge/linux-64::nest-simulator-3.8-py310h93aa6d4_1
#   numpy              conda-forge/linux-64::numpy-2.2.1-py310h5851e9f_0
#   openmpi            conda-forge/linux-64::openmpi-5.0.6-hd45feaf_100
#   pandas             conda-forge/linux-64::pandas-2.2.3-py310h5eaa309_1
#   patsy              conda-forge/noarch::patsy-1.0.1-pyhd8ed1ab_1
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhff2d567_1
#   python-tzdata      conda-forge/noarch::python-tzdata-2024.2-pyhd8ed1ab_1
#   pytz               conda-forge/noarch::pytz-2024.1-pyhd8ed1ab_0
#   rdma-core          conda-forge/linux-64::rdma-core-55.0-h5888daf_0
#   rhash              conda-forge/linux-64::rhash-1.4.5-hb9d3cd8_0
#   scipy              conda-forge/linux-64::scipy-1.14.1-py310hfcf56fc_2
#   six                conda-forge/noarch::six-1.17.0-pyhd8ed1ab_0
#   statsmodels        conda-forge/linux-64::statsmodels-0.14.4-py310hf462985_0
#   ucc                conda-forge/linux-64::ucc-1.3.0-h0f835a6_3
#   ucx                conda-forge/linux-64::ucx-1.17.0-h53fb5aa_4
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.12.14-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.12.14-pyhd8ed1ab_0
#   libarchive                               3.7.2-h2aa1ff5_1 --> 3.7.4-hfca40fe_0
#   libcurl                                  8.5.0-hca28451_0 --> 8.8.0-hca28451_0
#   libgcc-ng                               13.2.0-h807b86a_3 --> 14.2.0-h69a702a_1
#   libgomp                                 13.2.0-h807b86a_3 --> 14.2.0-h77fa898_1
#   libsolv                                 0.7.27-hfc55251_0 --> 0.7.30-h3509ff9_0
#   libsqlite                               3.44.2-h2797004_0 --> 3.47.2-hee588c1_0
#   libssh2                                 1.11.0-h0841786_0 --> 1.11.1-hf672d98_0
#   libxml2                                 2.12.3-h232c23b_0 --> 2.12.7-h4c95cb1_3
#   libzlib                                 1.2.13-hd590300_5 --> 1.3.1-hb9d3cd8_2
#   ncurses                                    6.4-h59595ed_2 --> 6.5-he02047a_1
#   openssl                                  3.2.0-hd590300_1 --> 3.4.0-hb9d3cd8_0
#   python                         3.10.13-hd12c33a_0_cpython --> 3.10.16-he725a3c_1_cpython
#   zstandard                          0.22.0-py310h1275a96_0 --> 0.23.0-py310ha39cb0e_1
#   zstd                                     1.5.5-hfc55251_0 --> 1.5.6-ha6fb4c9_0
#
# The following packages will be DOWNGRADED:
#
#   libnghttp2                              1.58.0-h47da74e_1 --> 1.58.0-h47da74e_0
#   tk                              8.6.13-noxft_h4845f30_101 --> 8.6.13-h2797004_0
#
#
#
# Downloading and Extracting Packages:
# python-3.10.16       | 24.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
# cmake-3.30.1         | 18.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# scipy-1.14.1         | 16.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# nest-simulator-3.8   | 13.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# pandas-2.2.3         | 12.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# statsmodels-0.14.4   | 10.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# numpy-2.2.1          | 7.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ucx-1.17.0           | 6.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# openmpi-5.0.6        | 4.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# python-3.10.16       | 24.0 MB   | :   0% 0.0006501682504795408/1 [00:00<04:57, 298.14s/it]
#
# scipy-1.14.1         | 16.0 MB   | :   0% 0.0009757263068652089/1 [00:00<03:14, 194.80s/it]
#
#
#
# pandas-2.2.3         | 12.4 MB   | :   0% 0.0012589298420159843/1 [00:00<02:31, 151.87s/it]
#
#
# nest-simulator-3.8   | 13.5 MB   | :   0% 0.0011597898645380445/1 [00:00<02:58, 178.43s/it]
# cmake-3.30.1         | 18.3 MB   | :  13% 0.12800278006037943/1 [00:00<00:01,  1.84s/it]
#
# python-3.10.16       | 24.0 MB   | :  10% 0.10077607882432882/1 [00:00<00:02,  2.45s/it]
#
#
#
# pandas-2.2.3         | 12.4 MB   | :  19% 0.1926162658284456/1 [00:00<00:01,  1.25s/it]
#
#
# nest-simulator-3.8   | 13.5 MB   | :  19% 0.19484469724239148/1 [00:00<00:01,  1.33s/it]
# cmake-3.30.1         | 18.3 MB   | :  28% 0.27989941239869637/1 [00:00<00:00,  1.12s/it]
#
#
#
# pandas-2.2.3         | 12.4 MB   | :  41% 0.4104111284972109/1 [00:00<00:00,  1.29it/s]
#
# python-3.10.16       | 24.0 MB   | :  22% 0.2230077099144825/1 [00:00<00:01,  1.50s/it]
#
#
# nest-simulator-3.8   | 13.5 MB   | :  38% 0.3769317059748645/1 [00:00<00:00,  1.09it/s]
# cmake-3.30.1         | 18.3 MB   | :  38% 0.38144828457993074/1 [00:00<00:00,  1.14s/it]
#
# scipy-1.14.1         | 16.0 MB   | :  48% 0.47713016405708714/1 [00:00<00:00,  1.15it/s]
#
#
#
# python-3.10.16       | 24.0 MB   | :  30% 0.3003777317215478/1 [00:00<00:01,  1.46s/it]
#
#
# nest-simulator-3.8   | 13.5 MB   | :  55% 0.5509001856555712/1 [00:00<00:00,  1.30it/s]
# cmake-3.30.1         | 18.3 MB   | :  59% 0.5905194920118838/1 [00:00<00:00,  1.26it/s]
#
# scipy-1.14.1         | 16.0 MB   | :  68% 0.6752026043507245/1 [00:00<00:00,  1.41it/s]
#
#
#
# python-3.10.16       | 24.0 MB   | :  45% 0.4512167658328013/1 [00:00<00:00,  1.09s/it]
#
#
# nest-simulator-3.8   | 13.5 MB   | :  82% 0.8188116443638594/1 [00:00<00:00,  1.74it/s]
# cmake-3.30.1         | 18.3 MB   | :  80% 0.7978839957096985/1 [00:00<00:00,  1.49it/s]
#
# python-3.10.16       | 24.0 MB   | :  61% 0.6105079872002888/1 [00:00<00:00,  1.13it/s]
# python-3.10.16       | 24.0 MB   | :  90% 0.8998328586636845/1 [00:00<00:00,  1.25it/s]
#
#
#
#
# statsmodels-0.14.4   | 10.4 MB   | :   0% 0.0015080722457178398/1 [00:01<12:42, 763.36s/it]
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :   0% 0.0020315996578123526/1 [00:01<09:58, 599.42s/it]
#
#
#
#
# statsmodels-0.14.4   | 10.4 MB   | :  21% 0.21414625889193323/1 [00:01<00:03,  4.24s/it]
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :  39% 0.386003934984347/1 [00:01<00:01,  2.47s/it]
#
#
#
#
# statsmodels-0.14.4   | 10.4 MB   | :  46% 0.4629781794353768/1 [00:01<00:00,  1.85s/it]
#
#
#
#
#
#
# numpy-2.2.1          | 7.5 MB    | :   0% 0.0020707120878576445/1 [00:01<11:18, 680.17s/it]
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | :  75% 0.7516918733905704/1 [00:01<00:00,  1.22s/it]
#
#
#
#
# statsmodels-0.14.4   | 10.4 MB   | :  78% 0.7781652787904053/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
# numpy-2.2.1          | 7.5 MB    | :  40% 0.3996474329565254/1 [00:01<00:01,  2.74s/it]
#
#
#
#
# statsmodels-0.14.4   | 10.4 MB   | :  99% 0.9862792486994671/1 [00:01<00:00,  1.13it/s]
#
#
#
#
#
#
# numpy-2.2.1          | 7.5 MB    | :  68% 0.6771228527294498/1 [00:01<00:00,  1.57s/it]
#
#
#
#
#
#
#
# ucx-1.17.0           | 6.9 MB    | :   0% 0.002272770464748545/1 [00:01<12:11, 733.19s/it]
#
#
#
#
#
#
# numpy-2.2.1          | 7.5 MB    | :  98% 0.9753053933809506/1 [00:01<00:00,  1.04s/it]
#
#
#
#
#
#
#
# ucx-1.17.0           | 6.9 MB    | :  34% 0.3386427992475332/1 [00:01<00:02,  3.75s/it]
#
#
#
#
#
#
#
# ucx-1.17.0           | 6.9 MB    | :  66% 0.6636489757065751/1 [00:01<00:00,  1.76s/it]
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :   0% 0.0029369833860743893/1 [00:01<10:54, 656.00s/it]
#
#
#
#
#
#
#
# ucx-1.17.0           | 6.9 MB    | :  92% 0.9159264972936636/1 [00:01<00:00,  1.25s/it]
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  41% 0.4082406906643401/1 [00:02<00:02,  3.59s/it]
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | :  96% 0.9633305506323997/1 [00:02<00:00,  1.34s/it]
#
#
#
#
#
#
#
#
#
# openmpi-5.0.6        | 4.3 MB    | :   0% 0.0036003046546858675/1 [00:02<09:53, 595.68s/it]
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0.004207828296772089/1 [00:02<08:31, 513.96s/it]
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0.004188487029213828/1 [00:02<08:37, 519.28s/it]
#
#
#
#
#
#
#
#
#
# openmpi-5.0.6        | 4.3 MB    | :  40% 0.3996338166701313/1 [00:02<00:02,  4.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | :  50% 0.5049393956126507/1 [00:02<00:01,  3.20s/it]
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :  83% 0.8335089188135517/1 [00:02<00:00,  1.98s/it]
#
#
#
#
#
#
#
#
#
# openmpi-5.0.6        | 4.3 MB    | :  96% 0.9612813428011266/1 [00:02<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | :   0% 0.00485247257230507/1 [00:02<08:11, 494.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | :  84% 0.8394777550087771/1 [00:02<00:00,  2.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.1 MB    | :   0% 0.004979656171518519/1 [00:02<08:23, 505.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | :   1% 0.005558673111072358/1 [00:02<07:38, 460.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | :   1% 0.0067551604783531/1 [00:02<06:16, 379.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.1 MB    | :  80% 0.8017246436144815/1 [00:02<00:00,  2.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   1% 0.011201624454327605/1 [00:02<03:54, 237.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | :  83% 0.8338009666608538/1 [00:02<00:00,  2.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.2 MB    | :   1% 0.012587323403709357/1 [00:02<03:34, 216.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# nest-simulator-3.8   | 13.5 MB   | : 100% 1.0/1 [00:04<00:00,  1.74it/s]
#
#
#
# pandas-2.2.3         | 12.4 MB   | : 100% 1.0/1 [00:06<00:00,  1.98it/s]
#
# scipy-1.14.1         | 16.0 MB   | : 100% 1.0/1 [00:06<00:00,  1.76it/s]
#
#
#
#
#
# ucc-1.3.0            | 7.7 MB    | : 100% 1.0/1 [00:07<00:00,  1.22s/it]
# cmake-3.30.1         | 18.3 MB   | : 100% 1.0/1 [00:09<00:00,  1.50it/s]
#
#
#
#
# statsmodels-0.14.4   | 10.4 MB   | : 100% 1.0/1 [00:10<00:00,  1.13it/s]
#
#
#
#
#
#
# numpy-2.2.1          | 7.5 MB    | : 100% 1.0/1 [00:11<00:00,  1.04s/it]
#
#
#
#
#
#
#
# ucx-1.17.0           | 6.9 MB    | : 100% 1.0/1 [00:11<00:00,  1.25s/it]
#
#
#
#
#
#
#
#
# libopenblas-0.3.28   | 5.3 MB    | : 100% 1.0/1 [00:12<00:00,  1.34s/it]
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:12<00:00,  1.98s/it]
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-14.2.0     | 3.7 MB    | : 100% 1.0/1 [00:12<00:00, 13.91s/it]
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.16       | 24.0 MB   | : 100% 1.0/1 [00:12<00:00,  1.25it/s]
#
#
#
#
#
#
#
#
#
# openmpi-5.0.6        | 4.3 MB    | : 100% 1.0/1 [00:13<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | : 100% 1.0/1 [00:14<00:00, 13.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.11.2      | 2.3 MB    | : 100% 1.0/1 [00:14<00:00, 13.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:15<00:00,  2.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.4.0        | 2.8 MB    | : 100% 1.0/1 [00:15<00:00,  2.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:15<00:00, 14.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:15<00:00, 14.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | : 100% 1.0/1 [00:15<00:00,  2.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.2 MB    | : 100% 1.0/1 [00:15<00:00, 15.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.2 MB    | : 100% 1.0/1 [00:15<00:00, 15.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# /
# To enable CUDA support, UCX requires the CUDA Runtime library (libcudart).
# The library can be installed with the appropriate command below:
#
# * For CUDA 11, run:    conda install cudatoolkit cuda-version=11
# * For CUDA 12, run:    conda install cuda-cudart cuda-version=12
#
#
# -
# To enable CUDA support, please follow UCX's instruction above.
#
# To additionally enable NCCL support, run:    conda install nccl
#
#
# \
# On Linux, Open MPI is built with CUDA awareness but it is disabled by default.
# To enable it, please set the environment variable
# OMPI_MCA_opal_cuda_support=true
# before launching your MPI processes.
# Equivalently, you can set the MCA parameter in the command line:
# mpiexec --mca opal_cuda_support 1 ...
# Note that you might also need to set UCX_MEMTYPE_CACHE=n for CUDA awareness via
# UCX. Please consult UCX documentation for further details.
#
#
# done
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.13            |       hb9d3cd8_0         547 KB  conda-forge
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     cairo-1.18.0               |       hbb29018_2         961 KB  conda-forge
#     contourpy-1.3.1            |  py310h3788b33_0         255 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     dbus-1.13.6                |       h5008d03_3         604 KB  conda-forge
#     double-conversion-3.3.0    |       h59595ed_0          77 KB  conda-forge
#     expat-2.6.4                |       h5888daf_0         135 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.55.3           |  py310h89163eb_1         2.2 MB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     graphite2-1.3.13           |    h59595ed_1003          95 KB  conda-forge
#     harfbuzz-8.5.0             |       hfac3d4d_0         1.5 MB  conda-forge
#     kiwisolver-1.4.7           |  py310h3788b33_0          70 KB  conda-forge
#     lcms2-2.16                 |       hb7c19ff_0         239 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hd590300_1          68 KB  conda-forge
#     libbrotlidec-1.1.0         |       hd590300_1          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hd590300_1         276 KB  conda-forge
#     libclang-cpp18.1-18.1.8    |default_hf981a13_5        18.3 MB  conda-forge
#     libclang13-19.1.2          |default_h9c6a7e4_1        11.3 MB  conda-forge
#     libcups-2.3.3              |       h4637d8d_4         4.3 MB  conda-forge
#     libdeflate-1.23            |       h4ddbbb0_0          71 KB  conda-forge
#     libdrm-2.4.124             |       hb9d3cd8_0         237 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libglib-2.80.2             |       hf974151_0         3.7 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     libllvm18-18.1.8           |       h8b73ec9_2        36.5 MB  conda-forge
#     libllvm19-19.1.2           |       ha7bfdaf_0        38.3 MB  conda-forge
#     libopengl-1.7.0            |       ha4b6fd6_2          50 KB  conda-forge
#     libpciaccess-0.18          |       hd590300_0          28 KB  conda-forge
#     libpng-1.6.44              |       hadc24fc_0         284 KB  conda-forge
#     libpq-16.3                 |       ha72fbe1_0         2.4 MB  conda-forge
#     libtiff-4.7.0              |       hd9ff511_3         418 KB  conda-forge
#     libwebp-base-1.5.0         |       h851e524_0         420 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxkbcommon-1.7.0         |       h2c5496b_1         579 KB  conda-forge
#     libxslt-1.1.39             |       h76b75d6_0         248 KB  conda-forge
#     matplotlib-3.10.0          |  py310hff52083_0          17 KB  conda-forge
#     matplotlib-base-3.10.0     |  py310h68603db_0         7.1 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     mysql-common-8.3.0         |       h70512c7_5         762 KB  conda-forge
#     mysql-libs-8.3.0           |       ha479ceb_5         1.5 MB  conda-forge
#     openjpeg-2.5.3             |       h5fbd93e_0         335 KB  conda-forge
#     pcre2-10.43                |       hcad00b1_0         929 KB  conda-forge
#     pillow-11.0.0              |  py310hfeaa1f3_0        40.7 MB  conda-forge
#     pixman-0.44.2              |       h29eaf8c_0         372 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pyparsing-3.2.0            |     pyhd8ed1ab_2          90 KB  conda-forge
#     pyside6-6.7.2              |  py310hfd10a26_4        10.1 MB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     qt6-main-6.7.2             |       h0f8cd61_2        44.8 MB  conda-forge
#     tornado-6.4.2              |  py310ha75aee5_0         635 KB  conda-forge
#     unicodedata2-15.1.0        |  py310ha75aee5_1         359 KB  conda-forge
#     wayland-1.23.1             |       h3e06ad9_0         314 KB  conda-forge
#     xcb-util-0.4.1             |       hb711507_2          19 KB  conda-forge
#     xcb-util-cursor-0.1.5      |       hb9d3cd8_0          20 KB  conda-forge
#     xcb-util-image-0.4.0       |       hb711507_2          24 KB  conda-forge
#     xcb-util-keysyms-0.4.1     |       hb711507_0          14 KB  conda-forge
#     xcb-util-renderutil-0.3.10 |       hb711507_0          17 KB  conda-forge
#     xcb-util-wm-0.4.2          |       hb711507_0          50 KB  conda-forge
#     xkeyboard-config-2.43      |       hb9d3cd8_0         380 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.5           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.10         |       h4f16b4b_1         818 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       239.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.13-hb9d3cd8_0
#   brotli             conda-forge/linux-64::brotli-1.1.0-hd590300_1
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hd590300_1
#   cairo              conda-forge/linux-64::cairo-1.18.0-hbb29018_2
#   contourpy          conda-forge/linux-64::contourpy-1.3.1-py310h3788b33_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   dbus               conda-forge/linux-64::dbus-1.13.6-h5008d03_3
#   double-conversion  conda-forge/linux-64::double-conversion-3.3.0-h59595ed_0
#   expat              conda-forge/linux-64::expat-2.6.4-h5888daf_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/linux-64::fonttools-4.55.3-py310h89163eb_1
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h59595ed_1003
#   harfbuzz           conda-forge/linux-64::harfbuzz-8.5.0-hfac3d4d_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.7-py310h3788b33_0
#   lcms2              conda-forge/linux-64::lcms2-2.16-hb7c19ff_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hd590300_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hd590300_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hd590300_1
#   libclang-cpp18.1   conda-forge/linux-64::libclang-cpp18.1-18.1.8-default_hf981a13_5
#   libclang13         conda-forge/linux-64::libclang13-19.1.2-default_h9c6a7e4_1
#   libcups            conda-forge/linux-64::libcups-2.3.3-h4637d8d_4
#   libdeflate         conda-forge/linux-64::libdeflate-1.23-h4ddbbb0_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.124-hb9d3cd8_0
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.80.2-hf974151_0
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   libllvm18          conda-forge/linux-64::libllvm18-18.1.8-h8b73ec9_2
#   libllvm19          conda-forge/linux-64::libllvm19-19.1.2-ha7bfdaf_0
#   libopengl          conda-forge/linux-64::libopengl-1.7.0-ha4b6fd6_2
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hd590300_0
#   libpng             conda-forge/linux-64::libpng-1.6.44-hadc24fc_0
#   libpq              conda-forge/linux-64::libpq-16.3-ha72fbe1_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hd9ff511_3
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.5.0-h851e524_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.7.0-h2c5496b_1
#   libxslt            conda-forge/linux-64::libxslt-1.1.39-h76b75d6_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.10.0-py310hff52083_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.10.0-py310h68603db_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   mysql-common       conda-forge/linux-64::mysql-common-8.3.0-h70512c7_5
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.3.0-ha479ceb_5
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.3-h5fbd93e_0
#   pcre2              conda-forge/linux-64::pcre2-10.43-hcad00b1_0
#   pillow             conda-forge/linux-64::pillow-11.0.0-py310hfeaa1f3_0
#   pixman             conda-forge/linux-64::pixman-0.44.2-h29eaf8c_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.0-pyhd8ed1ab_2
#   pyside6            conda-forge/linux-64::pyside6-6.7.2-py310hfd10a26_4
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   qt6-main           conda-forge/linux-64::qt6-main-6.7.2-h0f8cd61_2
#   tornado            conda-forge/linux-64::tornado-6.4.2-py310ha75aee5_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-15.1.0-py310ha75aee5_1
#   wayland            conda-forge/linux-64::wayland-1.23.1-h3e06ad9_0
#   xcb-util           conda-forge/linux-64::xcb-util-0.4.1-hb711507_2
#   xcb-util-cursor    conda-forge/linux-64::xcb-util-cursor-0.1.5-hb9d3cd8_0
#   xcb-util-image     conda-forge/linux-64::xcb-util-image-0.4.0-hb711507_2
#   xcb-util-keysyms   conda-forge/linux-64::xcb-util-keysyms-0.4.1-hb711507_0
#   xcb-util-renderut~ conda-forge/linux-64::xcb-util-renderutil-0.3.10-hb711507_0
#   xcb-util-wm        conda-forge/linux-64::xcb-util-wm-0.4.2-hb711507_0
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.43-hb9d3cd8_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.5-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.10-h4f16b4b_1
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#
#
#
# Downloading and Extracting Packages:
# qt6-main-6.7.2       | 44.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# pillow-11.0.0        | 40.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libllvm19-19.1.2     | 38.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libclang13-19.1.2    | 11.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pyside6-6.7.2        | 10.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libpq-16.3           | 2.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.5.0       | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-libs-8.3.0     | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 961 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.43          | 929 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.10   | 818 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-common-8.3.0   | 762 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# qt6-main-6.7.2       | 44.8 MB   | :   0% 0.000348460905138686/1 [00:00<08:31, 511.73s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :   0% 0.0008543832902986769/1 [00:00<03:22, 202.52s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :   0% 0.000428529979744478/1 [00:00<06:58, 418.87s/it]
# pillow-11.0.0        | 40.7 MB   | :   0% 0.0003841558412204001/1 [00:00<08:46, 526.64s/it]
#
# qt6-main-6.7.2       | 44.8 MB   | :   4% 0.040769925901226266/1 [00:00<00:05,  5.55s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :   9% 0.08629271232016637/1 [00:00<00:02,  2.57s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :   5% 0.053566247468059755/1 [00:00<00:04,  4.24s/it]
# pillow-11.0.0        | 40.7 MB   | :   6% 0.056470908659398814/1 [00:00<00:04,  4.30s/it]
#
# qt6-main-6.7.2       | 44.8 MB   | :  12% 0.1195220904625693/1 [00:00<00:02,  2.41s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :  23% 0.23153787167094145/1 [00:00<00:00,  1.24s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  13% 0.13113017380181027/1 [00:00<00:01,  2.25s/it]
# pillow-11.0.0        | 40.7 MB   | :  13% 0.13291792106225842/1 [00:00<00:02,  2.34s/it]
#
# qt6-main-6.7.2       | 44.8 MB   | :  18% 0.1839873579132262/1 [00:00<00:01,  2.02s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :  39% 0.38703563050530065/1 [00:00<00:00,  1.07it/s]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  23% 0.22669235928482886/1 [00:00<00:01,  1.60s/it]
# pillow-11.0.0        | 40.7 MB   | :  19% 0.19092545308653885/1 [00:00<00:01,  2.09s/it]
#
# qt6-main-6.7.2       | 44.8 MB   | :  25% 0.2491495471741605/1 [00:00<00:01,  1.83s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :  55% 0.5476596890814519/1 [00:00<00:00,  1.25it/s]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  31% 0.31196982525398/1 [00:00<00:00,  1.42s/it]
# pillow-11.0.0        | 40.7 MB   | :  26% 0.26237843955353324/1 [00:00<00:01,  1.86s/it]
#
# qt6-main-6.7.2       | 44.8 MB   | :  31% 0.30769097923745975/1 [00:00<00:01,  1.79s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :  68% 0.6800890990777468/1 [00:00<00:00,  1.25it/s]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  41% 0.4071034807572541/1 [00:00<00:00,  1.28s/it]
# pillow-11.0.0        | 40.7 MB   | :  34% 0.33690467275029085/1 [00:00<00:01,  1.66s/it]
#
# qt6-main-6.7.2       | 44.8 MB   | :  39% 0.38679160470394147/1 [00:00<00:00,  1.58s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | :  86% 0.8629271232016638/1 [00:00<00:00,  1.43it/s]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  49% 0.48895270688844944/1 [00:00<00:00,  1.36s/it]
# qt6-main-6.7.2       | 44.8 MB   | :  47% 0.4728614482731969/1 [00:00<00:00,  1.42s/it]
#
# libllvm19-19.1.2     | 38.3 MB   | :  56% 0.5641457056230054/1 [00:00<00:00,  1.24s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  58% 0.5785154726550453/1 [00:00<00:00,  1.28s/it]
# qt6-main-6.7.2       | 44.8 MB   | :  56% 0.5568405264116203/1 [00:00<00:00,  1.35s/it]
#
# libllvm19-19.1.2     | 38.3 MB   | :  66% 0.6551764526229549/1 [00:00<00:00,  1.22s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  66% 0.6595076388267517/1 [00:01<00:00,  1.30s/it]
# qt6-main-6.7.2       | 44.8 MB   | :  63% 0.6345473082575472/1 [00:01<00:00,  1.35s/it]
#
# libllvm19-19.1.2     | 38.3 MB   | :  74% 0.7384512166946576/1 [00:01<00:00,  1.23s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  75% 0.7546412943300258/1 [00:01<00:00,  1.23s/it]
# qt6-main-6.7.2       | 44.8 MB   | :  71% 0.7094664028623647/1 [00:01<00:00,  1.36s/it]
#
# libllvm19-19.1.2     | 38.3 MB   | :  82% 0.8205013518829528/1 [00:01<00:00,  1.25s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  84% 0.8377761104004545/1 [00:01<00:00,  1.26s/it]
# qt6-main-6.7.2       | 44.8 MB   | :  78% 0.7836885756569049/1 [00:01<00:00,  1.37s/it]
#
# libllvm19-19.1.2     | 38.3 MB   | :  91% 0.9074500026048777/1 [00:01<00:00,  1.23s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | :  94% 0.9384806556404068/1 [00:01<00:00,  1.17s/it]
# qt6-main-6.7.2       | 44.8 MB   | :  86% 0.8572138266411676/1 [00:01<00:00,  1.42s/it]
#
# libllvm19-19.1.2     | 38.3 MB   | :  99% 0.989500137793173/1 [00:01<00:00,  1.26s/it]
#
#
#
#
# libclang13-19.1.2    | 11.3 MB   | :   0% 0.001386166960696955/1 [00:01<17:02, 1023.53s/it]
# qt6-main-6.7.2       | 44.8 MB   | :  93% 0.9282998512894596/1 [00:01<00:00,  1.48s/it]
#
#
#
#
# qt6-main-6.7.2       | 44.8 MB   | : 100% 0.996598188696642/1 [00:01<00:00,  1.50s/it]
#
#
#
#
# libclang13-19.1.2    | 11.3 MB   | :  54% 0.5364466137897216/1 [00:01<00:00,  1.86s/it]
#
#
#
#
# libclang13-19.1.2    | 11.3 MB   | :  84% 0.8372448442609608/1 [00:01<00:00,  1.13s/it]
#
#
#
#
#
# pyside6-6.7.2        | 10.1 MB   | :   0% 0.0015510966785570826/1 [00:02<22:16, 1338.76s/it]
#
#
#
#
#
# pyside6-6.7.2        | 10.1 MB   | :  21% 0.21405134164087739/1 [00:02<00:05,  7.29s/it]
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | :   0% 0.002215537266434854/1 [00:02<16:50, 1012.50s/it]
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | :   0% 0.003625258385954602/1 [00:02<10:17, 619.82s/it]
#
#
#
#
#
# pyside6-6.7.2        | 10.1 MB   | :  41% 0.41104061981762685/1 [00:02<00:02,  3.44s/it]
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | :  53% 0.5317289439443649/1 [00:02<00:01,  3.15s/it]
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | :  60% 0.5981676336825094/1 [00:02<00:01,  2.80s/it]
#
#
#
#
#
# pyside6-6.7.2        | 10.1 MB   | :  73% 0.7290154389218287/1 [00:02<00:00,  1.67s/it]
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | :  84% 0.8441196985116793/1 [00:02<00:00,  1.86s/it]
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | :   0% 0.004187418677717254/1 [00:02<09:58, 601.46s/it]
#
#
#
#
#
#
#
#
#
# libpq-16.3           | 2.4 MB    | :   1% 0.006552449389887136/1 [00:02<06:36, 399.37s/it]
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.87s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.2 MB    | :   1% 0.006984769842369468/1 [00:02<06:23, 386.35s/it]
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   1% 0.010110434778315882/1 [00:02<04:30, 272.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.5.0       | 1.5 MB    | :   1% 0.010251250747695596/1 [00:02<04:27, 269.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-libs-8.3.0     | 1.5 MB    | :   1% 0.010693560693332254/1 [00:02<04:16, 259.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 961 KB    | :   2% 0.016646617030269532/1 [00:02<02:45, 168.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.10   | 818 KB    | :   2% 0.019562424479776103/1 [00:02<02:29, 152.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.43          | 929 KB    | :   2% 0.017230953034505024/1 [00:02<02:50, 173.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-common-8.3.0   | 762 KB    | :   2% 0.021001224131411467/1 [00:03<02:20, 143.11s/it]
#
#
#
#
# libclang13-19.1.2    | 11.3 MB   | : 100% 1.0/1 [00:03<00:00,  1.13s/it]
#
#
#
# libclang-cpp18.1-18. | 18.3 MB   | : 100% 1.0/1 [00:04<00:00,  1.43it/s]
#
# libllvm19-19.1.2     | 38.3 MB   | : 100% 1.0/1 [00:08<00:00,  1.26s/it]
#
#
# libllvm18-18.1.8     | 36.5 MB   | : 100% 1.0/1 [00:08<00:00,  1.17s/it]
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | : 100% 1.0/1 [00:08<00:00,  9.28s/it]
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | : 100% 1.0/1 [00:08<00:00,  9.28s/it]
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.1 MB    | : 100% 1.0/1 [00:09<00:00,  1.86s/it]
# pillow-11.0.0        | 40.7 MB   | : 100% 1.0/1 [00:10<00:00, 33.56s/it]
# pillow-11.0.0        | 40.7 MB   | : 100% 1.0/1 [00:10<00:00, 33.56s/it]
#
#
#
#
#
# pyside6-6.7.2        | 10.1 MB   | : 100% 1.0/1 [00:11<00:00, 14.70s/it]
#
#
#
#
#
# pyside6-6.7.2        | 10.1 MB   | : 100% 1.0/1 [00:11<00:00, 14.70s/it]
#
#
#
#
#
#
#
#
# libglib-2.80.2       | 3.7 MB    | : 100% 1.0/1 [00:11<00:00,  1.87s/it]
#
#
#
#
#
#
#
#
#
# libpq-16.3           | 2.4 MB    | : 100% 1.0/1 [00:12<00:00, 12.04s/it]
#
#
#
#
#
#
#
#
#
# libpq-16.3           | 2.4 MB    | : 100% 1.0/1 [00:12<00:00, 12.04s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.2 MB    | : 100% 1.0/1 [00:13<00:00, 12.80s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.2 MB    | : 100% 1.0/1 [00:13<00:00, 12.80s/it]
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:13<00:00, 12.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:13<00:00, 12.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-libs-8.3.0     | 1.5 MB    | : 100% 1.0/1 [00:13<00:00, 13.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-libs-8.3.0     | 1.5 MB    | : 100% 1.0/1 [00:13<00:00, 13.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 961 KB    | : 100% 1.0/1 [00:13<00:00, 13.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 961 KB    | : 100% 1.0/1 [00:13<00:00, 13.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.5.0       | 1.5 MB    | : 100% 1.0/1 [00:14<00:00, 13.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.5.0       | 1.5 MB    | : 100% 1.0/1 [00:14<00:00, 13.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.10   | 818 KB    | : 100% 1.0/1 [00:14<00:00, 14.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.10   | 818 KB    | : 100% 1.0/1 [00:14<00:00, 14.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-common-8.3.0   | 762 KB    | : 100% 1.0/1 [00:15<00:00, 14.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-common-8.3.0   | 762 KB    | : 100% 1.0/1 [00:15<00:00, 14.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.43          | 929 KB    | : 100% 1.0/1 [00:15<00:00, 14.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.7.2       | 44.8 MB   | : 100% 1.0/1 [00:19<00:00,  1.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
import matplotlib.pyplot
import nest
import numpy as np

# %%
# !python3 /content/run_microcircuit.py
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.8.0
#  Built: Aug 27 2024 04:32:09
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# Data will be written to: /content/data/
#   Directory already existed. Old data will be overwritten.
#
# Neuron numbers are scaled by a factor of 0.100.
# Indegrees are scaled by a factor of 0.100.
#   Weights and DC input are adjusted to compensate.
#
#
# Dec 28 21:18:50 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# RNG seed: 55
# Total number of virtual processes: 4
# Creating neuronal populations.
# Creating recording devices.
#   Creating spike recorders.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# Connecting Poisson generators for background input.
#
# Dec 28 21:18:51 NodeManager::prepare_nodes [Info]:
#     Preparing 2756 nodes for simulation.
# Simulating 500.0 ms.
#
# Dec 28 21:18:51 NodeManager::prepare_nodes [Info]:
#     Preparing 2756 nodes for simulation.
#
# Dec 28 21:18:51 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2756
#     Simulation time (ms): 500
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [ 100% ] Model time: 500.0 ms, Real-time factor: 7.1587
#
# Dec 28 21:18:59 SimulationManager::run [Info]:
#     Simulation finished.
# Simulating 1000.0 ms.
#
# Dec 28 21:18:59 NodeManager::prepare_nodes [Info]:
#     Preparing 2756 nodes for simulation.
#
# Dec 28 21:18:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2756
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [ 100% ] Model time: 1500.0 ms, Real-time factor: 7.1668
#
# Dec 28 21:19:16 SimulationManager::run [Info]:
#     Simulation finished.
# Interval to plot spikes: [600. 800.] ms
# Interval to compute firing rates: [ 500. 1500.] ms
# Mean rates: [415.073 204.268] spikes/s
# Standard deviation of rates: [  6.199 178.05 ] spikes/s
#
# Times of Rank 0:
#   Total time:          35.334 s
#   Time to initialize:  0.014 s
#   Time to create:      0.074 s
#   Time to connect:     0.386 s
#   Time to presimulate: 8.790 s
#   Time to simulate:    16.267 s
#   Time to evaluate:    9.803 s

# %%
import pandas as pd
import numpy as np

# Dati estratti dal file network_params.py
# Popolazioni e numero di neuroni
popolazioni = ["L4E", "L4I"]
num_neuroni = np.array([21915, 5479])  # Numero di neuroni per L4E e L4I

# Probabilità di connessione tra le popolazioni (L4E -> L4E, L4E -> L4I, L4I -> L4E, L4I -> L4I)
conn_probs = np.array(
    [
        [0.0497, 0.135],  # L4E to L4E and L4I
        [0.0794, 0.1597],  # L4I to L4E and L4I
    ]
)

# Calcolare il numero di connessioni
def calcola_connessioni(num_neuroni, conn_probs):
    num_connessioni = {}

    # Connessioni L4E -> L4E
    num_connessioni["L4E -> L4E"] = int(num_neuroni[0] * num_neuroni[0] * conn_probs[0, 0])

    # Connessioni L4E -> L4I
    num_connessioni["L4E -> L4I"] = int(num_neuroni[0] * num_neuroni[1] * conn_probs[0, 1])

    # Connessioni L4I -> L4E
    num_connessioni["L4I -> L4E"] = int(num_neuroni[1] * num_neuroni[0] * conn_probs[1, 0])

    # Connessioni L4I -> L4I
    num_connessioni["L4I -> L4I"] = int(num_neuroni[1] * num_neuroni[1] * conn_probs[1, 1])

    return num_connessioni

# Calcolare le connessioni
num_connessioni = calcola_connessioni(num_neuroni, conn_probs)

# Creare la tabella dei neuroni
tabella_neuroni = pd.DataFrame({
    "Popolazione": popolazioni,
    "Numero di neuroni": num_neuroni
})

# Creare la tabella delle connessioni
tabella_connessioni = pd.DataFrame({
    "Connessione": ["L4E -> L4E", "L4E -> L4I", "L4I -> L4E", "L4I -> L4I"],
    "Numero di connessioni": [
        num_connessioni["L4E -> L4E"],
        num_connessioni["L4E -> L4I"],
        num_connessioni["L4I -> L4E"],
        num_connessioni["L4I -> L4I"]
    ]
})

# Mostrare le tabelle
print("Tabella dei neuroni:")
print(tabella_neuroni)

print("\nTabella delle connessioni:")
print(tabella_connessioni)
# Out:
# Tabella dei neuroni:
#   Popolazione  Numero di neuroni
# 0         L4E              21915
# 1         L4I               5479
#
# Tabella delle connessioni:
#   Connessione  Numero di connessioni
# 0  L4E -> L4E               23869281
# 1  L4E -> L4I               16209758
# 2  L4I -> L4E                9533739
# 3  L4I -> L4I                4794104
